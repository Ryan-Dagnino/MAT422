# %% [markdown]
# <a href="https://colab.research.google.com/github/Ryan-Dagnino/MAT422/blob/main/MAT422_HW2_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Homework 2.4**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %% [markdown]
# # **MLE for Random Samples**
#
# Maximum likelihood estimation (MLE) is an effective approach of estimating
# the parameters of a probability distribution through maximizing a likelihood
# function. The point in the parameter space that maximizes the likelihood
# function is called the maximum likelihood estimate. The logic of maximum
# likelihood is both intuitive and flexible. As a result, the method has become
# a dominant means of statistical inference.

# %%
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.fit.html is the source for the example on MLE

rng = np.random.default_rng()
dist = stats.nbinom
shapes = (5, 0.5)
data = dist.rvs(*shapes, size=1000, random_state=rng)

bounds = [(0, 30), (0, 1)]
res = stats.fit(dist, data, bounds)

res.params
res.plot()
plt.show()

# %% [markdown]
# # **Linear Regression**
#
# Given input data points as pairs, we seek an affine function to fit the data and each x_i. We can minimize the criterion by finding the coefficients B_j.

# %%
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.linregress.html is the source for the example of linear regression

rng = np.random.default_rng()

x = rng.random(10)
y = 1.6*x + rng.random(10)

res = stats.linregress(x, y)

plt.plot(x, y, 'o', label='original data')
plt.plot(x, res.intercept + res.slope*x, 'r', label='fitted line')
plt.legend()
plt.show()
